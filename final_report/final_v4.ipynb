# %% [markdown]
# ### Final Project
# ### Topic - CSPNet implement in Super resolution
# - Author
#     - 109511054 王宏銘
#     - 109511085 洪鈺翔

# %%
import os
# Image
import numpy as np
from PIL import Image
import cv2
# Pytorch
import torch
import torch.nn as nn
import torchvision.transforms as tt
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
# tqdm
from tqdm import tqdm
# other
import math
# !pip install thop
import thop
# Tensor board
from torch.utils.tensorboard import SummaryWriter
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from thop) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->thop) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->thop) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->thop) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->thop) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->thop) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->thop) (1.3.0)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %% [markdown]
# ##### DIV2K dataset
# - Website : [link](https://data.vision.ee.ethz.ch/cvl/DIV2K/)

# %%
if not os.path.isdir('dataset'):
    os.mkdir('dataset')
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X4.zip -O ./dataset/DIV2K_train_LR_bicubic_X4.zip
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X4.zip -O ./dataset/DIV2K_valid_LR_bicubic_X4.zip
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip -O ./dataset/DIV2K_train_HR.zip
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip -O ./dataset/DIV2K_valid_HR.zip
# Out:
# --2023-12-11 12:35:16--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X4.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X4.zip [following]
# --2023-12-11 12:35:16--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X4.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246914039 (235M) [application/zip]
# Saving to: ‘./dataset/DIV2K_train_LR_bicubic_X4.zip’
#
# ./dataset/DIV2K_tra 100%[===================>] 235.47M   222MB/s    in 1.1s
#
# 2023-12-11 12:35:18 (222 MB/s) - ‘./dataset/DIV2K_train_LR_bicubic_X4.zip’ saved [246914039/246914039]
#
# --2023-12-11 12:35:18--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X4.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X4.zip [following]
# --2023-12-11 12:35:18--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X4.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31505881 (30M) [application/zip]
# Saving to: ‘./dataset/DIV2K_valid_LR_bicubic_X4.zip’
#
# ./dataset/DIV2K_val 100%[===================>]  30.05M   107MB/s    in 0.3s
#
# 2023-12-11 12:35:18 (107 MB/s) - ‘./dataset/DIV2K_valid_LR_bicubic_X4.zip’ saved [31505881/31505881]
#
# --2023-12-11 12:35:18--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip [following]
# --2023-12-11 12:35:18--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3530603713 (3.3G) [application/zip]
# Saving to: ‘./dataset/DIV2K_train_HR.zip’
#
# ./dataset/DIV2K_tra 100%[===================>]   3.29G   174MB/s    in 21s
#
# 2023-12-11 12:35:39 (159 MB/s) - ‘./dataset/DIV2K_train_HR.zip’ saved [3530603713/3530603713]
#
# --2023-12-11 12:35:39--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip [following]
# --2023-12-11 12:35:39--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 448993893 (428M) [application/zip]
# Saving to: ‘./dataset/DIV2K_valid_HR.zip’
#
# ./dataset/DIV2K_val 100%[===================>] 428.19M   242MB/s    in 1.8s
#
# 2023-12-11 12:35:41 (242 MB/s) - ‘./dataset/DIV2K_valid_HR.zip’ saved [448993893/448993893]

# %%
# !unzip ./dataset/DIV2K_train_LR_bicubic_X4.zip -d ./dataset/
# !unzip ./dataset/DIV2K_valid_LR_bicubic_X4.zip -d ./dataset/
# !unzip ./dataset/DIV2K_train_HR.zip -d ./dataset/
# !unzip ./dataset/DIV2K_valid_HR.zip -d ./dataset/
# Out:
# Archive:  ./dataset/DIV2K_train_LR_bicubic_X4.zip
#    creating: ./dataset/DIV2K_train_LR_bicubic/X4/
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0782x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0119x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0625x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0072x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0350x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0691x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0070x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0569x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0733x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0790x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0515x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0218x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0800x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0478x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0081x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0083x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0334x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0370x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0634x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0198x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0526x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0211x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0305x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0307x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0127x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0239x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0669x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0592x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0005x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0174x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0679x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0614x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0275x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0189x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0372x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0520x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0010x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0358x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0410x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0617x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0003x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0532x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0251x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0286x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0213x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0386x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0126x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0133x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0019x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0071x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0429x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0088x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0562x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0243x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0184x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0367x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0687x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0337x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0542x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0507x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0619x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0390x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0253x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0673x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0464x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0347x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0743x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0231x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0699x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0422x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0135x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0123x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0139x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0177x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0369x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0397x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0105x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0580x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0651x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0438x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0713x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0729x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0689x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0505x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0163x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0022x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0401x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0529x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0413x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0736x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0728x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0411x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0336x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0765x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0208x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0053x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0707x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0205x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0749x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0671x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0182x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0694x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0020x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0663x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0059x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0138x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0388x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0467x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0730x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0647x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0027x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0365x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0181x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0585x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0263x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0433x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0112x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0219x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0495x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0458x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0710x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0018x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0618x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0060x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0296x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0240x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0501x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0494x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0583x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0039x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0032x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0389x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0040x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0578x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0145x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0178x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0609x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0252x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0662x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0004x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0591x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0300x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0068x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0203x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0465x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0677x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0797x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0162x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0598x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0319x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0708x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0570x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0445x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0328x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0180x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0574x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0793x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0770x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0772x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0590x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0624x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0026x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0149x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0539x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0430x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0667x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0151x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0702x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0229x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0030x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0206x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0001x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0285x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0292x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0241x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0593x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0639x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0714x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0437x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0636x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0683x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0280x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0385x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0560x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0666x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0510x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0236x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0200x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0371x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0062x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0692x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0289x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0762x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0288x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0418x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0686x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0104x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0136x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0344x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0719x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0722x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0262x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0011x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0116x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0113x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0633x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0403x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0721x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0535x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0291x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0235x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0173x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0747x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0537x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0165x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0382x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0298x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0215x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0122x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0144x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0120x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0398x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0035x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0463x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0588x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0380x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0158x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0631x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0557x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0620x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0531x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0643x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0780x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0646x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0739x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0111x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0756x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0042x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0777x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0784x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0196x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0688x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0274x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0399x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0549x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0323x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0207x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0483x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0175x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0028x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0783x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0466x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0012x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0746x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0306x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0009x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0621x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0489x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0584x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0254x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0589x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0547x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0461x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0156x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0606x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0406x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0577x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0250x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0315x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0089x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0400x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0031x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0799x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0260x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0690x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0441x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0604x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0242x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0649x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0091x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0097x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0194x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0608x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0471x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0100x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0778x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0404x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0066x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0379x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0434x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0223x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0566x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0741x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0536x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0368x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0049x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0029x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0034x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0665x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0043x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0172x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0595x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0197x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0603x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0492x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0082x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0763x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0311x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0446x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0638x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0087x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0556x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0407x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0567x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0596x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0137x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0355x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0130x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0245x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0717x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0176x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0312x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0308x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0221x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0069x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0343x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0764x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0267x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0234x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0006x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0115x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0576x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0698x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0110x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0611x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0553x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0354x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0033x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0056x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0550x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0084x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0085x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0268x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0193x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0284x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0640x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0335x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0277x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0586x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0297x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0502x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0424x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0484x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0672x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0552x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0324x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0462x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0712x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0452x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0701x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0299x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0109x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0660x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0428x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0490x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0559x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0114x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0352x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0771x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0661x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0533x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0650x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0304x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0376x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0269x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0025x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0613x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0628x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0164x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0476x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0506x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0680x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0374x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0255x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0279x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0057x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0287x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0099x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0493x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0766x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0674x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0340x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0047x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0246x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0601x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0212x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0108x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0420x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0008x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0417x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0607x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0758x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0656x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0781x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0167x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0225x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0427x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0247x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0723x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0443x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0266x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0653x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0375x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0785x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0732x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0486x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0021x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0169x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0726x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0228x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0412x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0544x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0769x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0325x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0414x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0131x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0102x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0644x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0561x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0767x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0744x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0094x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0768x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0655x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0682x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0007x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0509x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0497x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0052x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0220x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0148x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0096x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0090x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0541x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0345x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0703x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0748x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0282x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0455x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0349x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0512x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0491x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0041x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0396x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0142x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0232x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0659x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0442x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0695x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0616x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0761x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0038x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0195x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0482x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0248x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0641x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0016x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0479x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0067x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0405x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0301x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0605x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0787x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0192x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0658x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0093x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0054x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0058x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0705x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0431x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0514x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0014x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0157x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0459x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0361x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0048x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0700x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0395x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0600x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0348x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0013x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0481x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0775x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0079x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0632x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0454x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0086x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0293x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0755x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0724x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0668x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0425x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0384x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0392x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0233x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0791x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0153x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0676x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0751x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0524x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0754x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0183x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0513x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0359x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0409x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0154x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0734x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0789x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0657x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0615x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0760x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0199x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0508x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0522x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0432x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0187x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0387x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0654x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0518x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0475x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0503x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0469x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0322x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0333x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0697x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0294x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0571x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0106x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0264x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0563x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0740x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0415x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0774x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0378x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0216x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0776x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0735x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0451x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0670x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0527x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0439x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0362x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0435x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0190x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0540x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0146x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0645x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0402x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0224x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0519x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0798x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0546x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0353x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0720x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0696x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0276x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0449x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0664x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0302x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0551x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0573x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0652x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0002x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0270x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0565x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0753x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0326x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0523x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0538x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0716x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0055x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0331x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0179x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0630x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0023x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0627x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0742x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0773x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0321x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0140x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0572x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0272x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0227x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0453x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0015x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0230x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0419x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0725x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0711x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0318x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0076x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0581x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0558x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0356x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0159x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0480x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0259x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0244x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0271x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0450x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0191x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0330x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0794x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0693x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0117x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0678x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0383x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0738x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0037x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0202x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0050x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0554x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0629x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0201x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0214x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0077x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0295x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0226x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0485x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0186x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0637x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0473x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0472x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0327x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0488x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0786x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0046x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0316x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0704x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0160x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0564x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0534x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0329x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0470x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0061x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0612x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0128x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0188x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0074x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0391x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0161x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0521x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0504x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0496x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0530x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0610x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0051x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0357x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0555x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0258x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0360x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0599x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0095x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0080x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0381x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0623x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0210x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0737x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0256x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0460x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0548x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0303x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0121x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0457x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0132x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0314x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0338x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0468x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0421x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0075x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0582x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0796x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0310x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0124x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0168x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0366x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0416x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0718x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0579x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0204x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0073x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0044x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0685x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0456x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0078x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0511x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0757x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0792x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0064x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0065x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0155x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0477x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0545x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0408x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0587x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0238x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0309x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0283x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0339x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0092x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0313x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0444x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0727x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0498x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0474x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0448x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0426x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0017x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0278x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0257x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0222x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0152x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0635x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0648x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0622x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0261x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0063x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0759x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0377x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0440x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0731x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0487x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0788x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0150x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0684x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0134x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0447x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0107x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0351x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0597x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0281x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0141x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0517x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0101x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0290x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0500x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0373x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0363x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0346x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0098x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0209x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0568x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0750x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0217x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0045x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0342x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0594x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0143x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0709x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0423x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0543x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0237x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0273x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0516x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0364x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0024x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0118x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0103x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0317x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0166x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0036x4.png
#   inflating: ./dataset/DIV2K_train_LR_bicubic/X4/0642x4.png
# ...
#   inflating: ./dataset/DIV2K_train_HR/0197.png
#   inflating: ./dataset/DIV2K_train_HR/0039.png
#   inflating: ./dataset/DIV2K_train_HR/0696.png
#   inflating: ./dataset/DIV2K_train_HR/0758.png
#   inflating: ./dataset/DIV2K_train_HR/0599.png
#   inflating: ./dataset/DIV2K_train_HR/0228.png
#   inflating: ./dataset/DIV2K_train_HR/0712.png
#   inflating: ./dataset/DIV2K_train_HR/0539.png
#   inflating: ./dataset/DIV2K_train_HR/0781.png
#   inflating: ./dataset/DIV2K_train_HR/0009.png
#   inflating: ./dataset/DIV2K_train_HR/0145.png
#   inflating: ./dataset/DIV2K_train_HR/0527.png
#   inflating: ./dataset/DIV2K_train_HR/0263.png
#   inflating: ./dataset/DIV2K_train_HR/0122.png
#   inflating: ./dataset/DIV2K_train_HR/0506.png
#   inflating: ./dataset/DIV2K_train_HR/0363.png
#   inflating: ./dataset/DIV2K_train_HR/0249.png
#   inflating: ./dataset/DIV2K_train_HR/0104.png
#   inflating: ./dataset/DIV2K_train_HR/0800.png
#   inflating: ./dataset/DIV2K_train_HR/0214.png
#   inflating: ./dataset/DIV2K_train_HR/0658.png
#   inflating: ./dataset/DIV2K_train_HR/0399.png
#   inflating: ./dataset/DIV2K_train_HR/0572.png
#   inflating: ./dataset/DIV2K_train_HR/0204.png
#   inflating: ./dataset/DIV2K_train_HR/0651.png
#   inflating: ./dataset/DIV2K_train_HR/0061.png
#   inflating: ./dataset/DIV2K_train_HR/0026.png
#   inflating: ./dataset/DIV2K_train_HR/0300.png
#   inflating: ./dataset/DIV2K_train_HR/0162.png
#   inflating: ./dataset/DIV2K_train_HR/0478.png
#   inflating: ./dataset/DIV2K_train_HR/0022.png
#   inflating: ./dataset/DIV2K_train_HR/0079.png
#   inflating: ./dataset/DIV2K_train_HR/0285.png
#   inflating: ./dataset/DIV2K_train_HR/0511.png
#   inflating: ./dataset/DIV2K_train_HR/0025.png
#   inflating: ./dataset/DIV2K_train_HR/0428.png
#   inflating: ./dataset/DIV2K_train_HR/0436.png
#   inflating: ./dataset/DIV2K_train_HR/0324.png
#   inflating: ./dataset/DIV2K_train_HR/0447.png
#   inflating: ./dataset/DIV2K_train_HR/0457.png
#   inflating: ./dataset/DIV2K_train_HR/0424.png
#   inflating: ./dataset/DIV2K_train_HR/0675.png
#   inflating: ./dataset/DIV2K_train_HR/0469.png
#   inflating: ./dataset/DIV2K_train_HR/0090.png
#   inflating: ./dataset/DIV2K_train_HR/0179.png
#   inflating: ./dataset/DIV2K_train_HR/0771.png
#   inflating: ./dataset/DIV2K_train_HR/0431.png
#   inflating: ./dataset/DIV2K_train_HR/0726.png
#   inflating: ./dataset/DIV2K_train_HR/0609.png
#   inflating: ./dataset/DIV2K_train_HR/0184.png
#   inflating: ./dataset/DIV2K_train_HR/0747.png
#   inflating: ./dataset/DIV2K_train_HR/0154.png
#   inflating: ./dataset/DIV2K_train_HR/0391.png
#   inflating: ./dataset/DIV2K_train_HR/0573.png
#   inflating: ./dataset/DIV2K_train_HR/0071.png
#   inflating: ./dataset/DIV2K_train_HR/0798.png
#   inflating: ./dataset/DIV2K_train_HR/0693.png
#   inflating: ./dataset/DIV2K_train_HR/0280.png
#   inflating: ./dataset/DIV2K_train_HR/0414.png
#   inflating: ./dataset/DIV2K_train_HR/0119.png
#   inflating: ./dataset/DIV2K_train_HR/0757.png
#   inflating: ./dataset/DIV2K_train_HR/0762.png
#   inflating: ./dataset/DIV2K_train_HR/0734.png
#   inflating: ./dataset/DIV2K_train_HR/0001.png
#   inflating: ./dataset/DIV2K_train_HR/0265.png
#   inflating: ./dataset/DIV2K_train_HR/0643.png
#   inflating: ./dataset/DIV2K_train_HR/0567.png
#   inflating: ./dataset/DIV2K_train_HR/0130.png
#   inflating: ./dataset/DIV2K_train_HR/0580.png
#   inflating: ./dataset/DIV2K_train_HR/0463.png
#   inflating: ./dataset/DIV2K_train_HR/0218.png
#   inflating: ./dataset/DIV2K_train_HR/0769.png
#   inflating: ./dataset/DIV2K_train_HR/0507.png
#   inflating: ./dataset/DIV2K_train_HR/0013.png
#   inflating: ./dataset/DIV2K_train_HR/0233.png
#   inflating: ./dataset/DIV2K_train_HR/0087.png
#   inflating: ./dataset/DIV2K_train_HR/0093.png
#   inflating: ./dataset/DIV2K_train_HR/0709.png
#   inflating: ./dataset/DIV2K_train_HR/0027.png
#   inflating: ./dataset/DIV2K_train_HR/0570.png
#   inflating: ./dataset/DIV2K_train_HR/0342.png
#   inflating: ./dataset/DIV2K_train_HR/0011.png
#   inflating: ./dataset/DIV2K_train_HR/0287.png
#   inflating: ./dataset/DIV2K_train_HR/0524.png
#   inflating: ./dataset/DIV2K_train_HR/0791.png
#   inflating: ./dataset/DIV2K_train_HR/0701.png
#   inflating: ./dataset/DIV2K_train_HR/0783.png
#   inflating: ./dataset/DIV2K_train_HR/0349.png
#   inflating: ./dataset/DIV2K_train_HR/0766.png
#   inflating: ./dataset/DIV2K_train_HR/0232.png
#   inflating: ./dataset/DIV2K_train_HR/0314.png
#   inflating: ./dataset/DIV2K_train_HR/0303.png
#   inflating: ./dataset/DIV2K_train_HR/0697.png
#   inflating: ./dataset/DIV2K_train_HR/0514.png
#   inflating: ./dataset/DIV2K_train_HR/0377.png
#   inflating: ./dataset/DIV2K_train_HR/0085.png
#   inflating: ./dataset/DIV2K_train_HR/0113.png
#   inflating: ./dataset/DIV2K_train_HR/0540.png
#   inflating: ./dataset/DIV2K_train_HR/0383.png
#   inflating: ./dataset/DIV2K_train_HR/0243.png
#   inflating: ./dataset/DIV2K_train_HR/0086.png
#   inflating: ./dataset/DIV2K_train_HR/0091.png
#   inflating: ./dataset/DIV2K_train_HR/0151.png
#   inflating: ./dataset/DIV2K_train_HR/0502.png
#   inflating: ./dataset/DIV2K_train_HR/0294.png
#   inflating: ./dataset/DIV2K_train_HR/0281.png
#   inflating: ./dataset/DIV2K_train_HR/0656.png
#   inflating: ./dataset/DIV2K_train_HR/0500.png
#   inflating: ./dataset/DIV2K_train_HR/0237.png
#   inflating: ./dataset/DIV2K_train_HR/0387.png
#   inflating: ./dataset/DIV2K_train_HR/0178.png
#   inflating: ./dataset/DIV2K_train_HR/0518.png
#   inflating: ./dataset/DIV2K_train_HR/0239.png
#   inflating: ./dataset/DIV2K_train_HR/0131.png
#   inflating: ./dataset/DIV2K_train_HR/0655.png
#   inflating: ./dataset/DIV2K_train_HR/0417.png
#   inflating: ./dataset/DIV2K_train_HR/0776.png
#   inflating: ./dataset/DIV2K_train_HR/0560.png
#   inflating: ./dataset/DIV2K_train_HR/0737.png
#   inflating: ./dataset/DIV2K_train_HR/0048.png
#   inflating: ./dataset/DIV2K_train_HR/0128.png
#   inflating: ./dataset/DIV2K_train_HR/0052.png
#   inflating: ./dataset/DIV2K_train_HR/0137.png
#   inflating: ./dataset/DIV2K_train_HR/0686.png
#   inflating: ./dataset/DIV2K_train_HR/0053.png
#   inflating: ./dataset/DIV2K_train_HR/0665.png
#   inflating: ./dataset/DIV2K_train_HR/0691.png
#   inflating: ./dataset/DIV2K_train_HR/0167.png
#   inflating: ./dataset/DIV2K_train_HR/0313.png
#   inflating: ./dataset/DIV2K_train_HR/0531.png
#   inflating: ./dataset/DIV2K_train_HR/0569.png
#   inflating: ./dataset/DIV2K_train_HR/0553.png
#   inflating: ./dataset/DIV2K_train_HR/0047.png
#   inflating: ./dataset/DIV2K_train_HR/0096.png
#   inflating: ./dataset/DIV2K_train_HR/0756.png
#   inflating: ./dataset/DIV2K_train_HR/0440.png
#   inflating: ./dataset/DIV2K_train_HR/0199.png
#   inflating: ./dataset/DIV2K_train_HR/0283.png
#   inflating: ./dataset/DIV2K_train_HR/0247.png
#   inflating: ./dataset/DIV2K_train_HR/0024.png
#   inflating: ./dataset/DIV2K_train_HR/0193.png
#   inflating: ./dataset/DIV2K_train_HR/0084.png
#   inflating: ./dataset/DIV2K_train_HR/0102.png
#   inflating: ./dataset/DIV2K_train_HR/0551.png
#   inflating: ./dataset/DIV2K_train_HR/0575.png
#   inflating: ./dataset/DIV2K_train_HR/0477.png
#   inflating: ./dataset/DIV2K_train_HR/0098.png
#   inflating: ./dataset/DIV2K_train_HR/0554.png
#   inflating: ./dataset/DIV2K_train_HR/0189.png
#   inflating: ./dataset/DIV2K_train_HR/0717.png
#   inflating: ./dataset/DIV2K_train_HR/0732.png
#   inflating: ./dataset/DIV2K_train_HR/0702.png
#   inflating: ./dataset/DIV2K_train_HR/0183.png
#   inflating: ./dataset/DIV2K_train_HR/0448.png
#   inflating: ./dataset/DIV2K_train_HR/0455.png
#   inflating: ./dataset/DIV2K_train_HR/0367.png
#   inflating: ./dataset/DIV2K_train_HR/0251.png
#   inflating: ./dataset/DIV2K_train_HR/0744.png
#   inflating: ./dataset/DIV2K_train_HR/0785.png
#   inflating: ./dataset/DIV2K_train_HR/0067.png
#   inflating: ./dataset/DIV2K_train_HR/0163.png
#   inflating: ./dataset/DIV2K_train_HR/0751.png
#   inflating: ./dataset/DIV2K_train_HR/0299.png
#   inflating: ./dataset/DIV2K_train_HR/0129.png
#   inflating: ./dataset/DIV2K_train_HR/0291.png
#   inflating: ./dataset/DIV2K_train_HR/0607.png
#   inflating: ./dataset/DIV2K_train_HR/0242.png
#   inflating: ./dataset/DIV2K_train_HR/0107.png
#   inflating: ./dataset/DIV2K_train_HR/0175.png
#   inflating: ./dataset/DIV2K_train_HR/0753.png
#   inflating: ./dataset/DIV2K_train_HR/0278.png
#   inflating: ./dataset/DIV2K_train_HR/0369.png
#   inflating: ./dataset/DIV2K_train_HR/0571.png
#   inflating: ./dataset/DIV2K_train_HR/0202.png
#   inflating: ./dataset/DIV2K_train_HR/0030.png
#   inflating: ./dataset/DIV2K_train_HR/0799.png
#   inflating: ./dataset/DIV2K_train_HR/0474.png
#   inflating: ./dataset/DIV2K_train_HR/0491.png
#   inflating: ./dataset/DIV2K_train_HR/0638.png
#   inflating: ./dataset/DIV2K_train_HR/0600.png
#   inflating: ./dataset/DIV2K_train_HR/0596.png
#   inflating: ./dataset/DIV2K_train_HR/0059.png
#   inflating: ./dataset/DIV2K_train_HR/0186.png
#   inflating: ./dataset/DIV2K_train_HR/0509.png
#   inflating: ./dataset/DIV2K_train_HR/0529.png
#   inflating: ./dataset/DIV2K_train_HR/0787.png
#   inflating: ./dataset/DIV2K_train_HR/0382.png
#   inflating: ./dataset/DIV2K_train_HR/0777.png
#   inflating: ./dataset/DIV2K_train_HR/0109.png
#   inflating: ./dataset/DIV2K_train_HR/0227.png
#   inflating: ./dataset/DIV2K_train_HR/0388.png
#   inflating: ./dataset/DIV2K_train_HR/0618.png
#   inflating: ./dataset/DIV2K_train_HR/0681.png
#   inflating: ./dataset/DIV2K_train_HR/0205.png
#   inflating: ./dataset/DIV2K_train_HR/0472.png
#   inflating: ./dataset/DIV2K_train_HR/0306.png
#   inflating: ./dataset/DIV2K_train_HR/0361.png
#   inflating: ./dataset/DIV2K_train_HR/0738.png
#   inflating: ./dataset/DIV2K_train_HR/0230.png
#   inflating: ./dataset/DIV2K_train_HR/0081.png
#   inflating: ./dataset/DIV2K_train_HR/0095.png
#   inflating: ./dataset/DIV2K_train_HR/0449.png
#   inflating: ./dataset/DIV2K_train_HR/0626.png
#   inflating: ./dataset/DIV2K_train_HR/0065.png
#   inflating: ./dataset/DIV2K_train_HR/0443.png
#   inflating: ./dataset/DIV2K_train_HR/0275.png
#   inflating: ./dataset/DIV2K_train_HR/0542.png
#   inflating: ./dataset/DIV2K_train_HR/0484.png
#   inflating: ./dataset/DIV2K_train_HR/0359.png
#   inflating: ./dataset/DIV2K_train_HR/0773.png
#   inflating: ./dataset/DIV2K_train_HR/0434.png
#   inflating: ./dataset/DIV2K_train_HR/0544.png
#   inflating: ./dataset/DIV2K_train_HR/0416.png
#   inflating: ./dataset/DIV2K_train_HR/0295.png
#   inflating: ./dataset/DIV2K_train_HR/0538.png
#   inflating: ./dataset/DIV2K_train_HR/0259.png
#   inflating: ./dataset/DIV2K_train_HR/0348.png
#   inflating: ./dataset/DIV2K_train_HR/0588.png
#   inflating: ./dataset/DIV2K_train_HR/0710.png
#   inflating: ./dataset/DIV2K_train_HR/0786.png
#   inflating: ./dataset/DIV2K_train_HR/0185.png
#   inflating: ./dataset/DIV2K_train_HR/0057.png
#   inflating: ./dataset/DIV2K_train_HR/0487.png
#   inflating: ./dataset/DIV2K_train_HR/0683.png
# Archive:  ./dataset/DIV2K_valid_HR.zip
#    creating: ./dataset/DIV2K_valid_HR/
#   inflating: ./dataset/DIV2K_valid_HR/0897.png
#   inflating: ./dataset/DIV2K_valid_HR/0887.png
#   inflating: ./dataset/DIV2K_valid_HR/0806.png
#   inflating: ./dataset/DIV2K_valid_HR/0834.png
#   inflating: ./dataset/DIV2K_valid_HR/0896.png
#   inflating: ./dataset/DIV2K_valid_HR/0881.png
#   inflating: ./dataset/DIV2K_valid_HR/0828.png
#   inflating: ./dataset/DIV2K_valid_HR/0833.png
#   inflating: ./dataset/DIV2K_valid_HR/0877.png
#   inflating: ./dataset/DIV2K_valid_HR/0826.png
#   inflating: ./dataset/DIV2K_valid_HR/0879.png
#   inflating: ./dataset/DIV2K_valid_HR/0812.png
#   inflating: ./dataset/DIV2K_valid_HR/0809.png
#   inflating: ./dataset/DIV2K_valid_HR/0865.png
#   inflating: ./dataset/DIV2K_valid_HR/0882.png
#   inflating: ./dataset/DIV2K_valid_HR/0830.png
#   inflating: ./dataset/DIV2K_valid_HR/0892.png
#   inflating: ./dataset/DIV2K_valid_HR/0859.png
#   inflating: ./dataset/DIV2K_valid_HR/0858.png
#   inflating: ./dataset/DIV2K_valid_HR/0816.png
#   inflating: ./dataset/DIV2K_valid_HR/0836.png
#   inflating: ./dataset/DIV2K_valid_HR/0857.png
#   inflating: ./dataset/DIV2K_valid_HR/0824.png
#   inflating: ./dataset/DIV2K_valid_HR/0823.png
#   inflating: ./dataset/DIV2K_valid_HR/0810.png
#   inflating: ./dataset/DIV2K_valid_HR/0900.png
#   inflating: ./dataset/DIV2K_valid_HR/0884.png
#   inflating: ./dataset/DIV2K_valid_HR/0890.png
#   inflating: ./dataset/DIV2K_valid_HR/0835.png
#   inflating: ./dataset/DIV2K_valid_HR/0848.png
#   inflating: ./dataset/DIV2K_valid_HR/0869.png
#   inflating: ./dataset/DIV2K_valid_HR/0878.png
#   inflating: ./dataset/DIV2K_valid_HR/0860.png
#   inflating: ./dataset/DIV2K_valid_HR/0851.png
#   inflating: ./dataset/DIV2K_valid_HR/0870.png
#   inflating: ./dataset/DIV2K_valid_HR/0867.png
#   inflating: ./dataset/DIV2K_valid_HR/0898.png
#   inflating: ./dataset/DIV2K_valid_HR/0818.png
#   inflating: ./dataset/DIV2K_valid_HR/0814.png
#   inflating: ./dataset/DIV2K_valid_HR/0895.png
#   inflating: ./dataset/DIV2K_valid_HR/0856.png
#   inflating: ./dataset/DIV2K_valid_HR/0891.png
#   inflating: ./dataset/DIV2K_valid_HR/0829.png
#   inflating: ./dataset/DIV2K_valid_HR/0825.png
#   inflating: ./dataset/DIV2K_valid_HR/0853.png
#   inflating: ./dataset/DIV2K_valid_HR/0894.png
#   inflating: ./dataset/DIV2K_valid_HR/0863.png
#   inflating: ./dataset/DIV2K_valid_HR/0883.png
#   inflating: ./dataset/DIV2K_valid_HR/0822.png
#   inflating: ./dataset/DIV2K_valid_HR/0837.png
#   inflating: ./dataset/DIV2K_valid_HR/0849.png
#   inflating: ./dataset/DIV2K_valid_HR/0899.png
#   inflating: ./dataset/DIV2K_valid_HR/0807.png
#   inflating: ./dataset/DIV2K_valid_HR/0864.png
#   inflating: ./dataset/DIV2K_valid_HR/0845.png
#   inflating: ./dataset/DIV2K_valid_HR/0871.png
#   inflating: ./dataset/DIV2K_valid_HR/0804.png
#   inflating: ./dataset/DIV2K_valid_HR/0815.png
#   inflating: ./dataset/DIV2K_valid_HR/0813.png
#   inflating: ./dataset/DIV2K_valid_HR/0868.png
#   inflating: ./dataset/DIV2K_valid_HR/0893.png
#   inflating: ./dataset/DIV2K_valid_HR/0876.png
#   inflating: ./dataset/DIV2K_valid_HR/0889.png
#   inflating: ./dataset/DIV2K_valid_HR/0843.png
#   inflating: ./dataset/DIV2K_valid_HR/0862.png
#   inflating: ./dataset/DIV2K_valid_HR/0875.png
#   inflating: ./dataset/DIV2K_valid_HR/0885.png
#   inflating: ./dataset/DIV2K_valid_HR/0866.png
#   inflating: ./dataset/DIV2K_valid_HR/0839.png
#   inflating: ./dataset/DIV2K_valid_HR/0873.png
#   inflating: ./dataset/DIV2K_valid_HR/0820.png
#   inflating: ./dataset/DIV2K_valid_HR/0852.png
#   inflating: ./dataset/DIV2K_valid_HR/0819.png
#   inflating: ./dataset/DIV2K_valid_HR/0808.png
#   inflating: ./dataset/DIV2K_valid_HR/0802.png
#   inflating: ./dataset/DIV2K_valid_HR/0821.png
#   inflating: ./dataset/DIV2K_valid_HR/0811.png
#   inflating: ./dataset/DIV2K_valid_HR/0847.png
#   inflating: ./dataset/DIV2K_valid_HR/0838.png
#   inflating: ./dataset/DIV2K_valid_HR/0827.png
#   inflating: ./dataset/DIV2K_valid_HR/0844.png
#   inflating: ./dataset/DIV2K_valid_HR/0872.png
#   inflating: ./dataset/DIV2K_valid_HR/0880.png
#   inflating: ./dataset/DIV2K_valid_HR/0854.png
#   inflating: ./dataset/DIV2K_valid_HR/0831.png
#   inflating: ./dataset/DIV2K_valid_HR/0841.png
#   inflating: ./dataset/DIV2K_valid_HR/0832.png
#   inflating: ./dataset/DIV2K_valid_HR/0801.png
#   inflating: ./dataset/DIV2K_valid_HR/0805.png
#   inflating: ./dataset/DIV2K_valid_HR/0888.png
#   inflating: ./dataset/DIV2K_valid_HR/0861.png
#   inflating: ./dataset/DIV2K_valid_HR/0817.png
#   inflating: ./dataset/DIV2K_valid_HR/0803.png
#   inflating: ./dataset/DIV2K_valid_HR/0842.png
#   inflating: ./dataset/DIV2K_valid_HR/0855.png
#   inflating: ./dataset/DIV2K_valid_HR/0840.png
#   inflating: ./dataset/DIV2K_valid_HR/0874.png
#   inflating: ./dataset/DIV2K_valid_HR/0846.png
#   inflating: ./dataset/DIV2K_valid_HR/0886.png
#   inflating: ./dataset/DIV2K_valid_HR/0850.png

# %%
# !rm ./dataset/DIV2K_train_LR_bicubic_X4.zip
# !rm ./dataset/DIV2K_valid_LR_bicubic_X4.zip
# !rm ./dataset/DIV2K_train_HR.zip
# !rm ./dataset/DIV2K_valid_HR.zip

# %% [markdown]
# ##### Preprocess

# %%
train_x_dir = './dataset/DIV2K_train_LR_bicubic/X4/'
train_y_dir = './dataset/DIV2K_train_HR/'
val_x_dir  = './dataset/DIV2K_valid_LR_bicubic/X4/'
val_y_dir  = './dataset/DIV2K_valid_HR/'
crop_tx_dir = './dataset/DIV2K_train_LR_bicubic/X4_crop_25/'
crop_ty_dir = './dataset/DIV2K_train_HR_crop_100/'
crop_vx_dir = './dataset/DIV2K_valid_LR_bicubic/X4_crop_200/'
crop_vy_dir = './dataset/DIV2K_valid_HR_crop_800/'

# Crop
def CROP(original_dir:str, crop_dir:str, crop_size=25):

    if os.path.isdir(crop_dir):
        return

    os.mkdir(crop_dir)
    M = crop_size
    N = crop_size

    for dirpath, dirnames, filenames in os.walk(original_dir):
        for filename in tqdm(filenames):
            img = cv2.imread(original_dir+filename)
            s = np.shape(img)
            image_copy = img
            imgheight, imgwidth, _ = np.shape(img)
            x1 = 0
            y1 = 0
            for y in range(0, imgheight, M):
                for x in range(0, imgwidth, N):
                    if (imgheight - y) < M or (imgwidth - x) < N:
                        break
                    y1 = y + M
                    x1 = x + N
                    # check whether the patch width or height exceeds the image width or height
                    if x1 >= imgwidth and y1 >= imgheight:
                        x1 = imgwidth - 1
                        y1 = imgheight - 1
                        #Crop into patches of size MxN
                        tiles = image_copy[y:y+M, x:x+N]
                        #Save each patch into file directory
                        cv2.imwrite(crop_dir+str(int(x/N))+'_'+str(int(y/M))+filename, tiles)
                    elif y1 >= imgheight: # when patch height exceeds the image height
                        y1 = imgheight - 1
                        #Crop into patches of size MxN
                        tiles = image_copy[y:y+M, x:x+N]
                        #Save each patch into file directory
                        cv2.imwrite(crop_dir+str(int(x/N))+'_'+str(int(y/M))+filename, tiles)
                    elif x1 >= imgwidth: # when patch width exceeds the image width
                        x1 = imgwidth - 1
                        #Crop into patches of size MxN
                        tiles = image_copy[y:y+M, x:x+N]
                        #Save each patch into file directory
                        cv2.imwrite(crop_dir+str(int(x/N))+'_'+str(int(y/M))+filename, tiles)
                    else:
                        #Crop into patches of size MxN
                        tiles = image_copy[y:y+M, x:x+N]
                        #Save each patch into file directory
                        cv2.imwrite(crop_dir+str(int(x/N))+'_'+str(int(y/M))+filename, tiles)
    return

def Remove_Plain_Color(lr_dir:str, hr_dir:str):

    for root, dirs, files in os.walk(lr_dir, topdown=True):
        lr_img_names = files
    for root, dirs, files in os.walk(hr_dir, topdown=True):
        hr_img_names = files

    lr_img_names.sort()
    hr_img_names.sort()

    for lr_file, hr_file in zip(lr_img_names, hr_img_names):

        lr_img = cv2.imread(lr_dir+lr_file)/255.
        hr_img = cv2.imread(hr_dir+hr_file)/255.

        lr_img = torch.asarray(lr_img).reshape(-1,lr_img.shape[2],lr_img.shape[0],lr_img.shape[1])
        hr_img = torch.asarray(hr_img).reshape(-1,hr_img.shape[2],hr_img.shape[0],hr_img.shape[1])

        lr_up = nn.functional.interpolate(lr_img, scale_factor=4, mode='bicubic')

        mse = np.square(lr_up.numpy() - hr_img.numpy()).mean()

        if mse < 1e-8:
            os.remove(lr_dir+lr_file)
            os.remove(hr_dir+hr_file)

CROP(original_dir=train_x_dir, crop_dir=crop_tx_dir, crop_size=25)
CROP(original_dir=train_y_dir, crop_dir=crop_ty_dir, crop_size=100)
CROP(original_dir=val_x_dir, crop_dir=crop_vx_dir, crop_size=200)
CROP(original_dir=val_y_dir, crop_dir=crop_vy_dir, crop_size=800)
Remove_Plain_Color(crop_tx_dir, crop_ty_dir)
#Remove_Plain_Color(crop_vx_dir, crop_vy_dir)
# Out:
# 100%|██████████| 800/800 [00:26<00:00, 30.16it/s]
# 100%|██████████| 800/800 [03:10<00:00,  4.20it/s]
# 100%|██████████| 100/100 [00:01<00:00, 95.06it/s]
# 100%|██████████| 100/100 [00:15<00:00,  6.33it/s]

# %% [markdown]
# ##### Fix seed

# %%
def set_seed(seed):
    #torch.backends.cudnn.deterministic = True
    #torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(123)

# %% [markdown]
# ##### Utils

# %%
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

#------------------------------------------------------------------------------------------------------------------------
#   PSNR measure function
#       - original code
#           + Website :         https://data.vision.ee.ethz.ch/cvl/DIV2K/
#           + Downloaded from : https://competitions.codalab.org/my/datasets/download/1ed1e509-86ed-4dc1-be3f-4bca1dbdbd83
#------------------------------------------------------------------------------------------------------------------------
def output_measures(img_orig:torch.Tensor, img_out:torch.Tensor):
    img_orig = img_orig.numpy()
    img_out = img_out.numpy()
    assert (img_orig.shape == img_out.shape), 'shape of images should be the same.'
    batch_size = img_orig.shape[0]
    psnr_sum = 0.
    for b in range(batch_size):
        squared_error = np.square(img_orig[b] - img_out[b])
        mse = np.mean(squared_error)
        psnr = 10 * np.log10(1.0 / mse)
        psnr_sum += psnr
    # Return sum of PSNR
    return psnr_sum

# %% [markdown]
# ##### Dataset

# %%
class ISR_Dataset(Dataset):
    def __init__(self, x_path, y_path, x_transform, y_transform):
        # x_path : low  res img
        # y_path : high res img
        self.x_path = x_path
        self.y_path = y_path
        self.x_transform = x_transform
        self.y_transform = y_transform
        # Load image names
        for root, dirs, files in os.walk(x_path, topdown=True):
            self.x_img_names = files
        for root, dirs, files in os.walk(y_path, topdown=True):
            self.y_img_names = files
        self.x_img_names.sort()
        self.y_img_names.sort()

        #print(self.x_img_names)
        #print(self.y_img_names)
        print('len_x : {}'.format(self.x_img_names.__len__()))
        print('len_y : {}'.format(self.y_img_names.__len__()))
        assert (self.x_img_names.__len__() == self.y_img_names.__len__()), 'The target length should be same as the input length'

        # Save data length
        self.data_len = self.x_img_names.__len__()

    def __getitem__(self, index):
        # Read image
        x_img = Image.open(self.x_path + self.x_img_names[index])
        y_img = Image.open(self.y_path + self.y_img_names[index])
        # Transformation
        x_img = x_img.convert('YCbCr').getchannel('Y') # Y channel
        y_img = y_img.convert('YCbCr').getchannel('Y') # Y channel
        x_img = self.x_transform(x_img)
        y_img = self.y_transform(y_img)

        return x_img, y_img

    def __len__(self):
        return self.data_len

# %%
transform = tt.ToTensor()
# Dataset
train_ds = ISR_Dataset(x_path=crop_tx_dir, y_path=crop_ty_dir, x_transform=transform, y_transform=transform)
valid_ds = ISR_Dataset(x_path=crop_vx_dir, y_path=crop_vy_dir, x_transform=transform, y_transform=transform)
# Dataloader
batch_size = 32
batch_size_val = 2
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True,  num_workers=max(os.cpu_count()-2,2), pin_memory=False)
valid_dl = DataLoader(valid_ds, batch_size=batch_size_val, shuffle=False, num_workers=max(os.cpu_count()-2,2), pin_memory=False)
# Out:
# len_x : 209535
# len_y : 209535
# len_x : 210
# len_y : 210

# %% [markdown]
# ##### Model

# %%
#=============================================================================
#   Source
#       -  https://github.com/yjn870/SRDenseNet-pytorch/blob/master/models.py
#=============================================================================
import torch.nn as nn
class ConvLayer(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size):
        super(ConvLayer, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, padding=kernel_size // 2)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        return self.relu(self.conv(x))


class DenseLayer(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size):
        super(DenseLayer, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, padding=kernel_size // 2)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        return torch.cat([x, self.relu(self.conv(x))], 1)


class DenseBlock(nn.Module):
    def __init__(self, in_channels, growth_rate, num_layers):
        super(DenseBlock, self).__init__()
        self.block = [ConvLayer(in_channels, growth_rate, kernel_size=3)]
        for i in range(num_layers - 1):
            self.block.append(DenseLayer(growth_rate * (i + 1), growth_rate, kernel_size=3))
        self.block = nn.Sequential(*self.block)

    def forward(self, x):
        return torch.cat([x, self.block(x)], 1)


class SRDenseNet(nn.Module):
    def __init__(self, num_channels=1, growth_rate=16, num_blocks=8, num_layers=8):
        super(SRDenseNet, self).__init__()

        # low level features
        self.conv = ConvLayer(num_channels, growth_rate * num_layers, 3)

        # high level features
        self.dense_blocks = []
        for i in range(num_blocks):
            self.dense_blocks.append(DenseBlock(growth_rate * num_layers * (i + 1), growth_rate, num_layers))
        self.dense_blocks = nn.Sequential(*self.dense_blocks)

        # bottleneck layer
        self.bottleneck = nn.Sequential(
            nn.Conv2d(growth_rate * num_layers + growth_rate * num_layers * num_blocks, 256, kernel_size=1),
            nn.ReLU(inplace=True)
        )

        # deconvolution layers
        self.deconv = nn.Sequential(
            nn.ConvTranspose2d(256, 256, kernel_size=3, stride=2, padding=3 // 2, output_padding=1),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(256, 256, kernel_size=3, stride=2, padding=3 // 2, output_padding=1),
            nn.ReLU(inplace=True)
        )

        # reconstruction layer
        self.reconstruction = nn.Conv2d(256, num_channels, kernel_size=3, padding=3 // 2)

        self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
                nn.init.kaiming_normal_(m.weight.data, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias.data)

    def forward(self, x):
        x = self.conv(x)
        x = self.dense_blocks(x)
        x = self.bottleneck(x)
        x = self.deconv(x)
        x = self.reconstruction(x)
        return x
#=====================================================================
# below is self-implement DenseNet
# reference https://github.com/yjn870/SRDenseNet-pytorch/blob/master/models.py
# reference https://github.com/Lornatang/SRDenseNet-PyTorch/blob/master/model.py
#=====================================================================
class denselayer(nn.Module):
  def __init__(self, num_input_feature, out_channel):
    super(denselayer, self).__init__()
    #self.norm1 = nn.BatchNorm2d(num_input_feature)
    self.relu1 = nn.ReLU(inplace=True)
    self.conv1 = nn.Conv2d(num_input_feature, out_channel, kernel_size=3, stride=1, padding = 1)
  def forward(self, x):
    out = torch.cat([x, self.relu1(self.conv1(x))], 1)
    return out
class denseblock(nn.Module):
  def __init__(self, num_input_feature, growth_rate, num_layer):
    super(denseblock, self).__init__()
    self.layers = nn.Sequential(
        nn.Conv2d(num_input_feature, growth_rate, kernel_size = 3, stride = 1, padding = 1),
        nn.ReLU(True)
    )
    for i in range(num_layer - 1):
      layer = denselayer((i + 1) * growth_rate, growth_rate )
      self.layers.add_module("denselayer%d" % (i + 1), layer)
  def forward(self, in_feature):
    return torch.cat([in_feature, self.layers(in_feature)], 1)
class CSP_block(nn.Module):
  def __init__(self, num_input_feature, growth_rate, num_layer, partial_ratio = 0.5):
    super(CSP_block, self).__init__()
    self.partial_ch1 = int(num_input_feature * partial_ratio)
    self.partial_ch2 = num_input_feature - self.partial_ch1
    self.dense = denseblock(self.partial_ch2, growth_rate, num_layer)
    trans_ch = self.partial_ch2 + growth_rate * num_layer
    self.conv1 = nn.Conv2d(trans_ch, trans_ch, kernel_size = 1, stride = 1, padding = 0)
  def forward(self, x):
    part1 = x[:, :self.partial_ch1, :, :]
    part2 = x[:, :self.partial_ch2, :, :]
    part2 = self.dense(part2)
    part2 = self.conv1(part2)
    out = torch.cat((part1,part2), 1)
    return out
#in paper we need 8 denseblock and each block has 8 conv layer
# I cancel the first conv layer and the classifier
class DenseNet(nn.Module):
  def __init__(self, num_channel, growth_rate = 4, num_block = 2, num_layer = 2):
    super(DenseNet, self).__init__()
    self.features = nn.Sequential(
        nn.Conv2d(num_channel, growth_rate * num_layer, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True),
    )
    self.dense_block = nn.Sequential()
    for i in range(num_block):
      self.dense_block.add_module("denseblock%d" % (i + 1) ,denseblock(growth_rate * num_layer * (i + 1), growth_rate, num_layer))
    self.BottleNeck = nn.Sequential(
        nn.Conv2d(growth_rate * num_layer + growth_rate * num_layer * num_block, 256, kernel_size = 1),
        nn.ReLU(inplace = True)
    )
    self.deconv1 = nn.ConvTranspose2d(256, 256, kernel_size = 3, stride = 2, padding = 1, output_padding = 1)
    self.relu1 = nn.ReLU(True)
    self.deconv2 = nn.ConvTranspose2d(256, 256, kernel_size = 3, stride = 2, padding = 1, output_padding = 1)
    self.relu2 = nn.ReLU(True)
    self.conv1 = nn.Conv2d(256, num_channel, kernel_size = 3, stride = 1, padding = 1)
    self._initialize_weights()
  def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
                nn.init.kaiming_normal_(m.weight.data, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias.data)
  def forward(self, x):
    x = self.features(x)
    x = self.dense_block(x)
    x = self.BottleNeck(x)
    x = self.deconv1(x)
    x = self.relu1(x)
    x = self.deconv2(x)
    x = self.relu2(x)
    x = self.conv1(x)
    return x
class SRCSPNet(nn.Module):
  def __init__(self, num_channel, growth_rate = 4, num_block = 8, num_layer = 8):
    super(SRCSPNet, self).__init__()
    self.features = nn.Sequential(
        nn.Conv2d(num_channel, growth_rate * num_layer, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True),
    )
    self.dense_block = nn.Sequential()

    self.dense_block.add_module("CSP_block1" ,CSP_block(128, growth_rate, num_layer))
    self.dense_block.add_module("CSP_block2" ,CSP_block(192, growth_rate, num_layer))
    self.dense_block.add_module("CSP_block3" ,CSP_block(224, growth_rate, num_layer))
    self.dense_block.add_module("CSP_block4" ,CSP_block(240, growth_rate, num_layer))
    self.dense_block.add_module("CSP_block5" ,CSP_block(248, growth_rate, num_layer))
    self.dense_block.add_module("CSP_block6" ,CSP_block(252, growth_rate, num_layer))
    self.dense_block.add_module("CSP_block7" ,CSP_block(254, growth_rate, num_layer))
    self.dense_block.add_module("CSP_block8" ,CSP_block(255, growth_rate, num_layer))
    self.BottleNeck = nn.Sequential(
        nn.Conv2d(383, 256, kernel_size = 1),
        nn.ReLU(inplace = True)
    )
    self.upsample = nn.Upsample(scale_factor = 4)
    self.deconv1 = nn.ConvTranspose2d(128, 128, kernel_size = 3, stride = 2, padding = 1, output_padding = 1)
    self.relu1 = nn.ReLU(True)
    self.deconv2 = nn.ConvTranspose2d(128, 128, kernel_size = 3, stride = 2, padding = 1, output_padding = 1)
    self.relu2 = nn.ReLU(True)
    self.conv1 = nn.Conv2d(256, num_channel, kernel_size = 3, stride = 1, padding = 1)
    self._initialize_weights()
  def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
                nn.init.kaiming_normal_(m.weight.data, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias.data)
  def forward(self, x):
    x = self.features(x)
    x = self.dense_block(x)
    x = self.BottleNeck(x)
    x1 = x[:, :128, :, :]
    x2 = x[:, :128, :, :]
    x1 = self.deconv1(x1)
    x1 = self.relu1(x1)
    x1 = self.deconv2(x1)
    x1 = self.relu2(x1)
    x2 = self.upsample(x2)
    x = torch.cat((x1, x2),1)
    x = self.conv1(x)
    return x

class Up_sample_model(nn.Module):
    def __init__(self):
        super(Up_sample_model, self).__init__()
        self.dummy = nn.Linear(1,1)

    def forward(self, x):
        return nn.functional.interpolate(x, scale_factor=4, mode='bicubic')

# %% [markdown]
# ##### Arguments and Settings

# %%
args = {
    'lr': 1e-4,
    'epochs': 10,
    'save_dir': './save/srdense_11_30_0/',
    'project_name': 'test_0',
    'train': True,
    'tensorboard': True,
    'device': 'cuda' if torch.cuda.is_available() else 'cpu',
}

#model = Up_sample_model()
model = DenseNet(num_channel=1, growth_rate=16, num_block=8, num_layer=8).to(args['device'])
#model = SRCSPNet(num_channel = 1, growth_rate = 16, num_block = 8, num_layer = 8).to(args['device'])
#print(model)
optimizer = torch.optim.AdamW(model.parameters(), lr=args['lr'], betas=(0.9,0.999), eps=1e-8, weight_decay=0.01)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=args['epochs'], eta_min=1e-7)
criterion = nn.L1Loss()
writer = SummaryWriter(log_dir=args['save_dir']+'tensorboard/', filename_suffix='_'+args['project_name'])

# %% [markdown]
# colab tensorboard

# %%
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(args['save_dir']+'tensorboard/')
)
# Install
! npm install -g localtunnel

# Tunnel port 6006 (TensorBoard assumed running)
get_ipython().system_raw('lt --port 6006 >> url.txt 2>&1 &')

# Get url
! cat url.txt
! curl ipv4.icanhazip.com
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# updated 1 package in 1.392s
# your url is: https://cold-rivers-guess.loca.lt
# your url is: https://full-swans-speak.loca.lt
# your url is: https://fifty-lions-rhyme.loca.lt
# /tools/node/lib/node_modules/localtunnel/bin/lt.js:81
#     throw err;
#     ^
#
# Error: connection refused: localtunnel.me:37039 (check your firewall settings)
#     at Socket.<anonymous> (/tools/node/lib/node_modules/localtunnel/lib/TunnelCluster.js:52:11)
#     at Socket.emit (events.js:315:20)
#     at emitErrorNT (internal/streams/destroy.js:106:8)
#     at emitErrorCloseNT (internal/streams/destroy.js:74:3)
#     at processTicksAndRejections (internal/process/task_queues.js:80:21)
# your url is: https://tricky-tigers-speak.loca.lt
# your url is: https://orange-berries-lose.loca.lt
# /tools/node/lib/node_modules/localtunnel/bin/lt.js:81
#     throw err;
#     ^
#
# Error: connection refused: localtunnel.me:39037 (check your firewall settings)
#     at Socket.<anonymous> (/tools/node/lib/node_modules/localtunnel/lib/TunnelCluster.js:52:11)
#     at Socket.emit (events.js:315:20)
#     at emitErrorNT (internal/streams/destroy.js:106:8)
#     at emitErrorCloseNT (internal/streams/destroy.js:74:3)
#     at processTicksAndRejections (internal/process/task_queues.js:80:21)
# your url is: https://hip-ideas-rule.loca.lt
# /tools/node/lib/node_modules/localtunnel/bin/lt.js:81
#     throw err;
#     ^
#
# Error: connection refused: localtunnel.me:42197 (check your firewall settings)
#     at Socket.<anonymous> (/tools/node/lib/node_modules/localtunnel/lib/TunnelCluster.js:52:11)
#     at Socket.emit (events.js:315:20)
#     at emitErrorNT (internal/streams/destroy.js:106:8)
#     at emitErrorCloseNT (internal/streams/destroy.js:74:3)
#     at processTicksAndRejections (internal/process/task_queues.js:80:21)
# 35.204.34.222

# %% [markdown]
# ##### Profiling model

# %%
input = torch.rand(1,1,256,256).to(args['device'])
print(input.size())
flops, params = thop.profile(model, inputs=[input])
print('FLOPs = ' + str(flops/1000**3) + 'G')
print('Params = ' + str(params/1000**2) + 'M')
# Out:
# torch.Size([1, 1, 256, 256])
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.ConvTranspose2d'>.
# FLOPs = 872.222294016G
# Params = 2.659585M

# %%
# Tensor board
data_it = iter(valid_dl)
img_x, img_y = next(data_it)
writer.add_graph(model, img_x.to(args['device']))
data_it = iter(valid_ds)
img_x, img_y = next(data_it)
writer.add_image('Low res image', img_x)
writer.add_image('High res image', img_y)

# %% [markdown]
# ##### Training

# %%
print('Device using : {}'.format(args['device']))

# Create folder
if not os.path.isdir('save'):
    os.mkdir('save')
if not os.path.isdir(args['save_dir']):
    os.mkdir(args['save_dir'])

best_val_loss = math.inf

# Training Loop
for epoch in range(args['epochs']):
    print('[Epoch {}]'.format(epoch))

    # Training
    if args['train'] == True:
        print('Train')
        model.train()
        loss_sum = 0.
        for data in tqdm(train_dl):
            img_out = model(data[0].to(args['device']))
            loss = criterion(img_out, data[1].to(args['device']))
            loss_sum += loss

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        avg_loss = loss_sum/len(train_dl)
        lr = get_lr(optimizer)
        print('avg_loss = {:e}'.format(avg_loss), end=' ')
        print('learning_rate = {:.6f}'.format(lr))

        if args['tensorboard']:
            writer.add_scalar('Loss/Train', avg_loss, epoch)
            writer.add_scalar('Learning rate', lr, epoch)

    # Validating
    print('Valid')
    model.eval()
    loss_sum = 0.
    psnr_sum = 0.
    img_tb_ready = False

    with torch.no_grad():
        for data in tqdm(valid_dl):
            img_out = model(data[0].to(args['device']))
            loss = criterion(img_out, data[1].to(args['device']))
            loss_sum += loss
            psnr_sum += output_measures(img_out.cpu(), data[1])

            if not img_tb_ready and args['tensorboard']:
                writer.add_image('Output_img', img_out[0], global_step=epoch)
                img_tb_ready = True

    avg_loss = loss_sum/len(valid_dl)
    psnr = psnr_sum/valid_ds.__len__()

    print('avg_loss = {:e}'.format(avg_loss))
    print('PSNR     = {:.2f} dB'.format(psnr))

    if args['tensorboard']:
        writer.add_scalar('Loss/Valid', avg_loss, epoch)
        writer.add_scalar('PSNR/Valid', psnr, epoch)

    # Save model
    torch.save(model.state_dict(), args['save_dir']+'model_save.pth')

    # Save best models
    if loss_sum/valid_ds.__len__() < best_val_loss:
        best_val_loss = loss_sum/len(valid_dl)
        torch.save(model.state_dict(), args['save_dir']+'best_model_save.pth')

    if args['train'] == False:
        break

    # Scheduler
    scheduler.step()

writer.close()
# Out:
# Device using : cuda
# [Epoch 0]
# Train
# 100%|██████████| 6548/6548 [06:23<00:00, 17.08it/s]
# avg_loss = 4.932886e-02 learning_rate = 0.000100
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 12.15it/s]
# avg_loss = 2.673650e-02
# PSNR     = 28.20 dB
# [Epoch 1]
# Train
# 100%|██████████| 6548/6548 [06:24<00:00, 17.03it/s]
# avg_loss = 4.602553e-02 learning_rate = 0.000098
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 12.37it/s]
# avg_loss = 2.568737e-02
# PSNR     = 28.52 dB
# [Epoch 2]
# Train
# 100%|██████████| 6548/6548 [06:24<00:00, 17.01it/s]
# avg_loss = 4.548967e-02 learning_rate = 0.000090
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 12.15it/s]
# avg_loss = 2.655088e-02
# PSNR     = 28.41 dB
# [Epoch 3]
# Train
# 100%|██████████| 6548/6548 [06:25<00:00, 16.96it/s]
# avg_loss = 4.516601e-02 learning_rate = 0.000079
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 12.34it/s]
# avg_loss = 2.507570e-02
# PSNR     = 28.73 dB
# [Epoch 4]
# Train
# 100%|██████████| 6548/6548 [06:25<00:00, 16.97it/s]
# avg_loss = 4.496079e-02 learning_rate = 0.000065
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 12.28it/s]
# avg_loss = 2.507000e-02
# PSNR     = 28.74 dB
# [Epoch 5]
# Train
# 100%|██████████| 6548/6548 [06:25<00:00, 16.99it/s]
# avg_loss = 4.480207e-02 learning_rate = 0.000050
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 12.11it/s]
# avg_loss = 2.475887e-02
# PSNR     = 28.82 dB
# [Epoch 6]
# Train
# 100%|██████████| 6548/6548 [06:25<00:00, 16.97it/s]
# avg_loss = 4.469620e-02 learning_rate = 0.000035
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 11.96it/s]
# avg_loss = 2.474115e-02
# PSNR     = 28.84 dB
# [Epoch 7]
# Train
# 100%|██████████| 6548/6548 [06:25<00:00, 16.99it/s]
# avg_loss = 4.460809e-02 learning_rate = 0.000021
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 12.18it/s]
# avg_loss = 2.462737e-02
# PSNR     = 28.87 dB
# [Epoch 8]
# Train
# 100%|██████████| 6548/6548 [06:25<00:00, 17.00it/s]
# avg_loss = 4.454610e-02 learning_rate = 0.000010
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 12.13it/s]
# avg_loss = 2.459310e-02
# PSNR     = 28.87 dB
# [Epoch 9]
# Train
# 100%|██████████| 6548/6548 [06:25<00:00, 17.00it/s]
# avg_loss = 4.450976e-02 learning_rate = 0.000003
# Valid
# 100%|██████████| 105/105 [00:08<00:00, 12.14it/s]
# avg_loss = 2.456417e-02
# PSNR     = 28.89 dB

# %% [markdown]
# upsample

# %%
writer = SummaryWriter(log_dir=args['save_dir']+'tensorboard/', filename_suffix='_'+args['project_name'])
model = nn.Upsample(scale_factor=4)
img_tb_ready = False
for data in tqdm(valid_dl):
  img_out = model(data[0].to(args['device']))
  writer.add_image('upsample result', img_out[0])
  if not img_tb_ready and args['tensorboard']:
                writer.add_image('upsample_img', img_out[0], global_step=epoch)
                img_tb_ready = True
writer.close()
# Out:
# 100%|██████████| 105/105 [00:06<00:00, 16.42it/s]

# %% [markdown]
# ##### Bicubic upsample : 27.22 dB
